# %%
# !git clone https://github.com/AJITKUMAR130012/yolov5.git # clone
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11182, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 11182 (delta 0), reused 73 (delta 0), pack-reused 11107
# Receiving objects: 100% (11182/11182), 18.05 MiB | 22.63 MiB/s, done.
# Resolving deltas: 100% (7396/7396), done.
# /content/yolov5/yolov5/yolov5

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# %cd yolov5
# Out:
# /content/yolov5/yolov5

# %%
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 2022-10-22 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/78.2 GB disk)

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-10-22 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/1191-receipt.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/1191-receipt.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2022-10-22 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/1191-receipt.jpg: 640x512 5 Totals, 15.5ms
# Speed: 0.6ms pre-process, 15.5ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4
